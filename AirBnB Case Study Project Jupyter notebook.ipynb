# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidance to answer the following questions.
#
# 1. Which hosts are the busiest and why?
# 2. How many neighborhood groups are available and which shows up the most?
# 3. Are private rooms the most popular in manhattan?
# 4. Which hosts are the busiest and based on their reviews?
# 5. Which neighorhood group has the highest average price?
# 6. Which neighborhood group has the highest total price?
# 7. Which top 5 hosts have the highest total price?
# 8. Who currently has no (zero) availability with a review count of 100 or more?
# 9. What host has the highest total of prices and where are they located?
# 10. When did Danielle from Queens last receive a review?
#
# You will be given **4 hours** to complete this assignment.
# **Be Advised** I will go dark for this intire assignment time period. That said, any questions that you would like to ask about the data, or the project **MUST** be asked before the time starts. Once the time has started, I can no longer give information.
#
# This is to similate what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv('AB_NYC_2019.csv')
air_bnb.head(20)
# Out:
#       id                                              name  host_id  \
# 0   2539                Clean & quiet apt home by the park     2787
# 1   2595                             Skylit Midtown Castle     2845
# 2   3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3   3831                   Cozy Entire Floor of Brownstone     4869
# 4   5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5   5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6   5121                                   BlissArtsSpace!     7356
# 7   5178                  Large Furnished Room Near B'way      8967
# 8   5203                Cozy Clean Guest Room - Family Apt     7490
# 9   5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 10  5295                  Beautiful 1br on Upper West Side     7702
# 11  5441                   Central Manhattan/near Broadway     7989
# 12  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# ...

# %%
# How many neighborhood groups are available and which shows up the most?

host_listings = air_bnb[['host_name', 'calculated_host_listings_count']].groupby('host_name').mean().sort_values('calculated_host_listings_count', ascending=False).head(5)
host_listings
# Out:
#               calculated_host_listings_count
# host_name
# Sonder (NYC)                       327.00000
# Blueground                         232.00000
# Kazuya                             103.00000
# Kara                               102.65035
# Sonder                              96.00000

# %%
# Are private rooms the most popular in manhattan?

air_bnb[['room_type','neighbourhood_group', 'id']].groupby(['neighbourhood_group','room_type']).count()
# Out:
#                                         id
# neighbourhood_group room_type
# Bronx               Entire home/apt    379
#                     Private room       652
#                     Shared room         60
# Brooklyn            Entire home/apt   9559
#                     Private room     10132
#                     Shared room        413
# Manhattan           Entire home/apt  13199
#                     Private room      7982
#                     Shared room        480
# Queens              Entire home/apt   2096
#                     Private room      3372
#                     Shared room        198
# Staten Island       Entire home/apt    176
#                     Private room       188
#                     Shared room          9

# %%
# Which hosts are the busiest and based on their reviews?

air_bnb[['host_name', 'reviews_per_month']].groupby(['host_name']).mean().sort_values('reviews_per_month', ascending=False).head(5)
# Out:
#            reviews_per_month
# host_name
# Row NYC            18.620000
# Nalicia            18.126667
# Dona               13.990000
# Aisling            13.420000
# Malini             13.150000

# %%
#Which neighorhood group has the highest average price?

air_bnb[['neighbourhood_group', 'price']].groupby('neighbourhood_group').mean().sort_values('price', ascending=False)
# Out:
#                           price
# neighbourhood_group
# Manhattan            196.875814
# Brooklyn             124.383207
# Staten Island        114.812332
# Queens                99.517649
# Bronx                 87.496792

# %%
# Which neighbor hood group has the highest total price?
display(air_bnb[['neighbourhood_group', 'price']].groupby('neighbourhood_group').max().sort_values('price', ascending=False))
# Out:
#                      price
# neighbourhood_group
# Brooklyn             10000
# Manhattan            10000
# Queens               10000
# Staten Island         5000
# Bronx                 2500

# %%
#Which top 5 hosts have the highest total price?
display(air_bnb[['host_name', 'price']].groupby('host_name').sum().sort_values('price', ascending=False).head(5))
display(air_bnb[['host_name', 'id', 'price']].groupby('host_name').max().sort_values('price', ascending=False).head(5))
# Out:
#               price
# host_name
# Sonder (NYC)  82795
# Blueground    70331
# Michael       66895
# David         65844
# Alex          52563
#                  id  price
# host_name
# Kathrine    7003697  10000
# Erin       34668348  10000
# Jelena     34680877  10000
# Amy        36205851   9999
# Olson       4737930   9999

# %%
# Who currently has no (zero) availability with a review count of 100 or more?

air_bnb.loc[(air_bnb['availability_365'] == 0) & (air_bnb['number_of_reviews'] > 100)].head(17)
# Out:
#          id                                      name  host_id  \
# 8      5203        Cozy Clean Guest Room - Family Apt     7490
# 94    20913        Charming 1 bed GR8 WBurg LOCATION!    79402
# 132   30031          NYC artists’ loft with roof deck   129352
# 174   44221            Financial District Luxury Loft   193722
# 180   45556     Fort Greene, Brooklyn: Center Bedroom    67778
# 220   57468           Modern, Large East Village Loft   239208
# 250   62461               B NYC Staten Alternative...   303939
# 357   99070       Comfortable Cozy Space in El Barrio   522065
# 415  140425              Holiday Time in NY - Oh My!!   683975
# 462  163627  Blue Room in Awesome Artist's Apartment!   242506
# 471  166172           LG Private Room/Family Friendly   792159
# 657  250259                 Pre-War Williamsburg Loft  1311398
# 696  258284         Fresh, Clean Brooklyn Garden Apt.  1358312
# 701  258740          Spacious room in beautiful apt!   1360043
# ...

# %%
# What host has the highest total of prices and where are they located?

display(air_bnb[['host_name','host_id', "price"]].groupby('host_name').sum().sort_values('price', ascending=False).head(5))
# Out:
#                   host_id  price
# host_name
# Sonder (NYC)  71782340547  82795
# Blueground    24924786136  70331
# Michael       22673153604  66895
# David         28633613354  65844
# Alex          19850092761  52563

# %%
# When did Danielle from Queens last receive a review?
display(air_bnb.loc[(air_bnb['host_name'] == 'Danielle') & (air_bnb['neighbourhood_group'] == 'Queens') ])
# Out:
#              id                                               name    host_id  \
# 7086    5115372  Comfy Room Family Home LGA Airport NO CLEANING...   26432133
# 16349  13151075                    ASTORIA APARTMENT OUTDOOR SPACE   18051286
# 20403  16276632  Cozy Room Family Home LGA Airport NO CLEANING FEE   26432133
# 21517  17222454   Sun Room Family Home LGA Airport NO CLEANING FEE   26432133
# 22068  17754072                Bed in Family Home Near LGA Airport   26432133
# 22469  18173787  Cute Tiny Room Family Home by LGA NO CLEANING FEE   26432133
# 27021  21386105  Quiet & clean 1br haven with balcony near the ...  154256662
# 33861  26814763  One bedroom with full bed / 1 stop from Manhattan  201647469
#
#       host_name neighbourhood_group     neighbourhood  latitude  longitude  \
# 7086   Danielle              Queens     East Elmhurst  40.76374  -73.87103
# 16349  Danielle              Queens           Astoria  40.77221  -73.92901
# ...

# %% [markdown]
# ## Further Questions
#
# 1. Which host has the most listings?

# %%
listings_count = air_bnb.groupby('host_name').sum()['calculated_host_listings_count'].to_frame()

display(listings_count.sort_values('calculated_host_listings_count', ascending = False, kind = 'mergesort').head(1))
# Out:
#               calculated_host_listings_count
# host_name
# Sonder (NYC)                          106929

# %% [markdown]
# 2. How many listings have completely open availability?

# %%
avail_open = air_bnb.sort_values('availability_365', ascending = False, kind = 'mergesort')
display(avail_open.head(1294))
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 36        11452                        Clean and Quiet in Brooklyn       7355
# 38        11943                          Country space in the city      45445
# 97        21644                          Upper Manhattan, New York      82685
# ...         ...                                                ...        ...
# 48698  36388748            Private Times Square Room with Pool/Gym  217557021
# 48744  36415840         A BEAUTIFUL SPACE IN HEART OF WILLIAMSBURG  223715460
# 48844  36453952    West Village Studio on quiet cobblestone street  115491896
# 48868  36473253                       Heaven for you(only for guy)  261338177
# 48880  36481315  The Raccoon Artist Studio in Williamsburg New ...  208514239
#
# ...

# %% [markdown]
# 3. What room_types have the highest review numbers?

# %%
reviews_count_room = air_bnb.groupby('room_type').sum()['number_of_reviews'].to_frame()

display(reviews_count_room)
# Out:
#                  number_of_reviews
# room_type
# Entire home/apt             580403
# Private room                538346
# Shared room                  19256

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --
#
# In conclusion:
#
# Manhatten and Brooklyn have the most number of listings, number of reviews, and the highest prices.
